# %% [markdown]
# <a href="https://colab.research.google.com/github/drpetros11111/Practical-Computer-Vision/blob/drpp_study/PracticalCompVision1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# loads and read an image from path to file
img =  cv2.imread('/content/flower.png')

# %%
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [239, 239, 238],
#         [239, 239, 238],
#         [239, 239, 238]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [239, 239, 238],
#         [239, 239, 238],
#         [239, 239, 238]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [239, 239, 238],
#         [239, 239, 238],
#         [239, 239, 238]],
#
#        ...,
#
#        [[239, 239, 238],
#         [239, 239, 238],
#         [239, 239, 238],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[239, 239, 238],
#         [239, 239, 238],
#         [239, 239, 238],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[239, 239, 238],
#         [239, 239, 238],
#         [239, 239, 238],
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow # Import the cv2_imshow function

# Load the image
img = cv2.imread('/content/flower.png')

# Convert the image to grayscale
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
import cv2
from google.colab.patches import cv2_imshow # Import the cv2_imshow function

# Load the image
img = cv2.imread('/content/flower.png')

# Convert the image to grayscale
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Display the grayscale image using cv2_imshow instead of cv2.imshow
cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=L size=360x296>
